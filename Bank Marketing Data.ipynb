# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading Dataset
Bank_Marketing_Data = pd.read_csv("D:\\DS with Py\\Data Science Datasets\\bank_marketing.csv")
Bank_Marketing_Data
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
Bank_Marketing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
Bank_Marketing_Data.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
Bank_Marketing_Data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
# changing the target variable string to Bool
Bank_Marketing_Data['y'] = Bank_Marketing_Data['y'].replace({'yes': 1, 'no': 0}).astype(int)

# %%
# Distribution of Target Variable
plt.figure(figsize= (12,6))
sns.distplot(Bank_Marketing_Data['y'])
plt.title("Distribution of Target variable Y ")
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16340\389610276.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Bank_Marketing_Data['y'])
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribution of Target variable Y ')

# %%
#for col in Bank_Marketing_Data.select_dtypes(include=['int32']).columns:
 #   Bank_Marketing_Data[col] = Bank_Marketing_Data[col].astype('category')

# %% [markdown]
# # Data Analysis

# %%
Bank_Marketing_Data.shape
# Out:
# (45211, 17)

# %%
Bank_Marketing_Data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
Bank_Marketing_Data.groupby(['age'])['y'].agg(['sum','count']).reset_index().head()
# Out:
#    age  sum  count
# 0   18    7     12
# 1   19   11     35
# 2   20   15     50
# 3   21   22     79
# 4   22   40    129

# %%
Bank_Marketing_Data['y'].sum()
# Out:
# 5289

# %%
# Get the number of distinct (unique) values in each column
Bank_Marketing_Data['age'].unique()
# Out:
# array([58, 44, 33, 47, 35, 28, 42, 43, 41, 29, 53, 57, 51, 45, 60, 56, 32,
#        25, 40, 39, 52, 46, 36, 49, 59, 37, 50, 54, 55, 48, 24, 38, 31, 30,
#        27, 34, 23, 26, 61, 22, 21, 20, 66, 62, 83, 75, 67, 70, 65, 68, 64,
#        69, 72, 71, 19, 76, 85, 63, 90, 82, 73, 74, 78, 80, 94, 79, 77, 86,
#        95, 81, 18, 89, 84, 87, 92, 93, 88], dtype=int64)

# %%
Bank_Marketing_Data['age'].sum()
# Out:
# 1850767

# %%
Bank_Marketing_Data.groupby(['job'])['y'].agg(['sum','count']).reset_index()
# Out:
#               job   sum  count
# 0          admin.   631   5171
# 1     blue-collar   708   9732
# 2    entrepreneur   123   1487
# 3       housemaid   109   1240
# 4      management  1301   9458
# 5         retired   516   2264
# 6   self-employed   187   1579
# 7        services   369   4154
# 8         student   269    938
# 9      technician   840   7597
# 10     unemployed   202   1303
# 11        unknown    34    288

# %%
Bank_Marketing_Data(['job'].management).sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 Bank_Marketing_Data(['job'].management).sum()
#
# AttributeError: 'list' object has no attribute 'management'

# %%
# Get the number of distinct (unique) values in each column in list
Bank_Marketing_Data['job'].unique().tolist()
# Out:
# ['management',
#  'technician',
#  'entrepreneur',
#  'blue-collar',
#  'unknown',
#  'retired',
#  'admin.',
#  'services',
#  'self-employed',
#  'unemployed',
#  'housemaid',
#  'student']

# %%
Bank_Marketing_Data.groupby(['marital'])['y'].agg(['sum','count']).reset_index()
# Out:
#     marital   sum  count
# 0  divorced   622   5207
# 1   married  2755  27214
# 2    single  1912  12790

# %%
# Get the number of distinct (unique) values in each column in list
Bank_Marketing_Data['marital'].unique().tolist()
# Out:
# ['married', 'single', 'divorced']

# %%
Bank_Marketing_Data.groupby(['education'])['y'].agg(['sum','count']).reset_index()
# Out:
#    education   sum  count
# 0    primary   591   6851
# 1  secondary  2450  23202
# 2   tertiary  1996  13301
# 3    unknown   252   1857

# %%
# Get the number of distinct (unique) values in each column in list
Bank_Marketing_Data['education'].unique().tolist()
# Out:
# ['tertiary', 'secondary', 'unknown', 'primary']

# %%
Bank_Marketing_Data.groupby(['default'])['y'].agg(['sum','count']).reset_index()
# Out:
#   default   sum  count
# 0      no  5237  44396
# 1     yes    52    815

# %%
Bank_Marketing_Data.groupby(['balance'])['y'].agg(['sum','count']).reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 Bank_Marketing_Data.groupby(['balance'])['y'].agg(['sum','count']).reset_index()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:255, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     253 kwargs["engine"] = engine
#     254 kwargs["engine_kwargs"] = engine_kwargs
# --> 255 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     256 if relabeling:
#     257     # columns is not narrowed by mypy from relabeling flag
#     258     assert columns is not None  # for mypy
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:360, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     358     for idx, (name, func) in enumerate(arg):
#     359         key = base.OutputKey(label=name, position=idx)
# ...

# %%
Bank_Marketing_Data['balance'].sum()
# Out:
# 61589682

# %%
Bank_Marketing_Data.groupby(['housing'])['y'].agg(['sum','count']).reset_index()
# Out:
#   housing   sum  count
# 0      no  3354  20081
# 1     yes  1935  25130

# %%
Bank_Marketing_Data.groupby(['loan'])['y'].agg(['sum','count']).reset_index()
# Out:
#   loan   sum  count
# 0   no  4805  37967
# 1  yes   484   7244

# %%
Bank_Marketing_Data.groupby(['contact'])['y'].agg(['sum','count']).reset_index()
# Out:
#      contact   sum  count
# 0   cellular  4369  29285
# 1  telephone   390   2906
# 2    unknown   530  13020

# %%
# Get the number of distinct (unique) values in each column in list
Bank_Marketing_Data['contact'].unique().tolist()
# Out:
# ['unknown', 'cellular', 'telephone']

# %%
Bank_Marketing_Data.groupby(['day'])['y'].agg(['sum','count']).reset_index().head()
# Out:
#    day  sum  count
# 0    1   90    322
# 1    2  182   1293
# 2    3  178   1079
# 3    4  230   1445
# 4    5  215   1910

# %%
Bank_Marketing_Data.groupby(['month'])['y'].agg(['sum','count']).reset_index()
# Out:
#    month  sum  count
# 0    apr  577   2932
# 1    aug  688   6247
# 2    dec  100    214
# 3    feb  441   2649
# 4    jan  142   1403
# 5    jul  627   6895
# 6    jun  546   5341
# 7    mar  248    477
# 8    may  925  13766
# 9    nov  403   3970
# 10   oct  323    738
# 11   sep  269    579

# %%
# Get the number of distinct (unique) values in each column in list
Bank_Marketing_Data['month'].unique().tolist()
# Out:
# ['may',
#  'jun',
#  'jul',
#  'aug',
#  'oct',
#  'nov',
#  'dec',
#  'jan',
#  'feb',
#  'mar',
#  'apr',
#  'sep']

# %%
Bank_Marketing_Data.groupby(['duration'])['y'].agg(['sum','count']).reset_index().head()
# Out:
#    duration  sum  count
# 0         0    0      3
# 1         1    0      2
# 2         2    0      3
# 3         3    0      4
# 4         4    0     15

# %%
# Get the number of distinct (unique) values in each column in list
Bank_Marketing_Data['duration'].unique()
# Out:
# array([ 261,  151,   76, ..., 1298, 1246, 1556], dtype=int64)

# %%
Bank_Marketing_Data['duration'].sum()
# Out:
# 11671811

# %%
Bank_Marketing_Data.groupby(['campaign'])['y'].agg(['sum','count']).reset_index().head()
# Out:
#    campaign   sum  count
# 0         1  2561  17544
# 1         2  1401  12505
# 2         3   618   5521
# 3         4   317   3522
# 4         5   139   1764

# %%
Bank_Marketing_Data['campaign'].sum()
# Out:
# 124956

# %%
Bank_Marketing_Data.groupby(['pdays'])['y'].agg(['sum','count']).reset_index().head()
# Out:
#    pdays   sum  count
# 0     -1  3384  36954
# 1      1     6     15
# 2      2     2     37
# 3      3     0      1
# 4      4     1      2

# %%
Bank_Marketing_Data['pdays'].sum()
# Out:
# 1817384

# %%
Bank_Marketing_Data.groupby(['previous'])['y'].agg(['sum','count']).reset_index().head()
# Out:
#    previous   sum  count
# 0         0  3384  36954
# 1         1   583   2772
# 2         2   456   2106
# 3         3   294   1142
# 4         4   171    714

# %%
Bank_Marketing_Data['previous'].sum()
# Out:
# 26237

# %%
Bank_Marketing_Data.groupby(['poutcome'])['y'].agg(['sum','mean','count']).reset_index()
# Out:
#   poutcome   sum      mean  count
# 0  failure   618  0.126097   4901
# 1    other   307  0.166848   1840
# 2  success   978  0.647253   1511
# 3  unknown  3386  0.091615  36959

# %%
# Get the number of distinct (unique) values in each column in list
Bank_Marketing_Data['poutcome'].unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %%
Bank_Marketing_Data.groupby(['y'])['y'].agg(['sum','count']).reset_index()
# Out:
#    y   sum  count
# 0  0     0  39922
# 1  1  5289   5289

# %% [markdown]
# # Splitting the dataset into Numerical and Categorical Features

# %% [markdown]
# ## Numerical features

# %%
Numerical_features = Bank_Marketing_Data.select_dtypes(include = ['integer']).columns.tolist()
print("No of Numerical Features:",len(Numerical_features))
Bank_Marketing_Data[Numerical_features].head()
# Out:
# No of Numerical Features: 8
#    age  balance  day  duration  campaign  pdays  previous  y
# 0   58     2143    5       261         1     -1         0  0
# 1   44       29    5       151         1     -1         0  0
# 2   33        2    5        76         1     -1         0  0
# 3   47     1506    5        92         1     -1         0  0
# 4   33        1    5       198         1     -1         0  0

# %%
Bank_Marketing_Data[Numerical_features].columns.tolist()
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous', 'y']

# %%
Bank_Marketing_Data[Numerical_features].isnull().sum()
# Out:
# age         0
# balance     0
# day         0
# duration    0
# campaign    0
# pdays       0
# previous    0
# y           0
# dtype: int64

# %% [markdown]
# ## Categorical Features

# %%
Categorical_features = Bank_Marketing_Data.select_dtypes(include = ['object']).columns.tolist()
print("No of Categorical Features:", len(Categorical_features))
Bank_Marketing_Data[Categorical_features].head()
# Out:
# No of Categorical Features: 9
#             job  marital  education default housing loan  contact month  \
# 0    management  married   tertiary      no     yes   no  unknown   may
# 1    technician   single  secondary      no     yes   no  unknown   may
# 2  entrepreneur  married  secondary      no     yes  yes  unknown   may
# 3   blue-collar  married    unknown      no     yes   no  unknown   may
# 4       unknown   single    unknown      no      no   no  unknown   may
#
#   poutcome
# 0  unknown
# 1  unknown
# 2  unknown
# 3  unknown
# 4  unknown

# %%
Bank_Marketing_Data[Categorical_features].columns.tolist()
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome']

# %%
Bank_Marketing_Data[Categorical_features].isnull().sum()
# Out:
# job          0
# marital      0
# education    0
# default      0
# housing      0
# loan         0
# contact      0
# month        0
# poutcome     0
# dtype: int64

# %% [markdown]
# # Features Visualization

# %% [markdown]
# ## Numerical Features visualization

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'y' , y = 'age', data = Bank_Marketing_Data, palette = 'Blues')
plt.title("Relationship between Age and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between Age and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'y' , y = 'balance', data = Bank_Marketing_Data, palette = 'Blues')
plt.title("Relationship between balance and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between balance and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'y' , y = 'day', data = Bank_Marketing_Data, palette = 'Blues')
plt.title("Relationship between day and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between day and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'y' , y = 'duration', data = Bank_Marketing_Data, palette = 'Blues')
plt.title("Relationship between duration and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between duration and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'y' , y = 'campaign', data = Bank_Marketing_Data, palette = 'Blues')
plt.title("Relationship between campagin and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between campagin and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'y' , y = 'pdays', data = Bank_Marketing_Data, palette = 'Blues')
plt.title("Relationship between pdays and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between pdays and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'y' , y = 'previous', data = Bank_Marketing_Data, palette = 'Blues')
plt.title("Relationship between previos and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between previos and y from Bank Marketing')

# %% [markdown]
# ## Categorical Features Visualization

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'y' , x= 'job', data = Bank_Marketing_Data, palette = 'viridis')
plt.title("Relationship between job and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between job and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'y' , x = 'marital', data = Bank_Marketing_Data, palette = 'viridis')
plt.title("Relationship between marital and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between marital and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'y' , x = 'education', data = Bank_Marketing_Data, palette = 'viridis')
plt.title("Relationship between education and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between education and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'y' , x = 'default', data = Bank_Marketing_Data, palette = 'viridis')
plt.title("Relationship between default and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between default and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'y' , x = 'housing', data = Bank_Marketing_Data, palette = 'viridis')
plt.title("Relationship between housing and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between housing and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'y' , x = 'loan', data = Bank_Marketing_Data, palette = 'viridis')
plt.title("Relationship between loan and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between loan and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'y' , x = 'contact', data = Bank_Marketing_Data, palette = 'viridis')
plt.title("Relationship between contact and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between contact and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'y' , x = 'month', data = Bank_Marketing_Data, palette = 'viridis')
plt.title("Relationship between month and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between month and y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'y' , x = 'poutcome', data = Bank_Marketing_Data, palette = 'viridis')
plt.title("Relationship between poutcome and y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Relationship between poutcome and y from Bank Marketing')

# %% [markdown]
# # Outliers Detection

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'age' , data = Bank_Marketing_Data, palette = 'Set3')
plt.title("Outliers detection for y from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Outliers detection for y from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'balance' , data = Bank_Marketing_Data, palette = 'deep')
plt.title("Outliers detection for balance from Bank Marketing")
# Out:
# Text(0.5, 1.0, 'Outliers detection for balance from Bank Marketing')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'day' , data = Bank_Marketing_Data, palette = 'muted')
plt.title("Outliers detection for day from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for day from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'duration' , data = Bank_Marketing_Data, palette = 'pastel')
plt.title("Outliers detection for duration from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for duration from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'campaign' , data = Bank_Marketing_Data, palette = 'bright')
plt.title("Outliers detection for campaign from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for campaign from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'pdays' , data = Bank_Marketing_Data, palette = 'pastel')
plt.title("Outliers detection for pdays from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for pdays from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'previous' , data = Bank_Marketing_Data, palette = 'Set2')
plt.title("Outliers detection for previous from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for previous from Student Performance')

# %%
# Computes correlation matrix for numerical columns using Heatmap

plt.figure(figsize=(12, 10))
correlation_matrix = Bank_Marketing_Data[Numerical_features].corr()  # Computes correlation matrix for numerical columns
sns.heatmap(correlation_matrix, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title('Heatmap of Correlation Matrix')
plt.show()
